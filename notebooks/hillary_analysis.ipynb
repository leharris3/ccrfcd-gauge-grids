# %%
import pandas as pd


df = pd.read_csv("/playpen/mufan/levi/tianlong-chen-lab/nws-lv-precip-forecasting/ccrfcd-gauge-grids/_hillary.csv")

# %%
df['gauge_qpe'].max()
# Out:
# np.float64(0.0)

# %%
df.hist("mrms_qpe")
# Out:
# array([[<Axes: title={'center': 'mrms_qpe'}>]], dtype=object)
