# %%
import sounderpy as spy


year  = '2011' 
month = '04'
day   = '28'
hour  = '0'
station = 'JAN'

clean_data = spy.get_obs_data(station, year, month, day, hour)
spy.build_sounding(clean_data)
# Out:
# > OBSERVED DATA ACCESS FUNCTION
#   -----------------------------------
#     > PROFILE FOUND: JAN on 04/28/2011 at 0z | From UW
#     > COMPLETE --------
#     > RUNTIME: 00:00:03
#     > SUMMARY: 0Z Launch for KJAN, JACKSON at 04-28-2011-0Z
#
#     > THERMODYNAMICS ---------------------------------------------
#     --- SBCAPE: 4063.3 | MUCAPE: 4063.3 | MLCAPE: 3471.7 | MUECAPE: 3073.8
#     --- MU 0-3: 319.2 | MU 0-6: 1054.3 | SB 0-3: 319.2 | SB 0-6: 1054.3
#
#     > KINEMATICS -------------------------------------------------
#     --- 0-500 SRW: 36.8 knot | 0-500 SWV: 0.01 | 0-500 SHEAR: 23.9 | 0-500 SRH: 55.6
#     --- 1-3km SRW: 21.7 knot | 1-3km SWV: 0.009 | 1-3km SHEAR: 35.5 | | 1-3km SRH: 183.4
#     ==============================================================
#
# > SOUNDING PLOTTER FUNCTION
#   ---------------------------------
# - no radar data available -
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
#     > COMPLETE --------
#     > RUNTIME: 00:00:13
