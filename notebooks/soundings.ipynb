# %%
import sounderpy as spy


year  = '2021' 
month = '01'
day   = '22'
hour  = '12'
station = 'VEF'

clean_data = spy.get_obs_data(station, year, month, day, hour)
# Out:
# > OBSERVED DATA ACCESS FUNCTION
#   -----------------------------------
#     > PROFILE FOUND: VEF on 01/22/2021 at 12z | From UW
#     > COMPLETE --------
#     > RUNTIME: 00:00:02
#     > SUMMARY: 12Z Launch for KVEF, LAS VEGAS at 01-22-2021-12Z
#
#     > THERMODYNAMICS ---------------------------------------------
#     --- SBCAPE: 0.0 | MUCAPE: 0.0 | MLCAPE: 0.0 | MUECAPE: --
#     --- MU 0-3: 0.0 | MU 0-6: 0.0 | SB 0-3: 0.0 | SB 0-6: 0.0
#
#     > KINEMATICS -------------------------------------------------
#     --- 0-500 SRW: 26.6 knot | 0-500 SWV: 0.02 | 0-500 SHEAR: 18.5 | 0-500 SRH: 134.0
#     --- 1-3km SRW: 14.0 knot | 1-3km SWV: 0.008 | 1-3km SHEAR: 14.8 | | 1-3km SRH: -27.2
# ...

# %%
clean_data
# Out:
# {'p': <Quantity([932.  928.  925.  915.  908.5 875.9 850.  813.5 794.  783.7 771.  757.
#   754.8 739.  726.6 718.  700.  699.5 696.  680.  673.1 663.  647.5 598.6
#   556.  553.4 539.  534.  531.  523.  502.  500.  493.  489.  487.  482.
#   479.  472.  470.2 467.  459.  441.  432.  418.  400.  393.  384.  380.7
#   374.  369.  363.  348.9 343.  315.  305.2 300.  299.  276.  258.  250.
#   240.  234.  225.  212.  207.  202.  200.1 200.  192.  182.  167.  162.
#   157.9 156.  150.  136.7 134.  129.  124.1 121.  118.2 117.  110.  100. ], 'hectopascal')>,
#  'z': <Quantity([  697   735   763   854   914  1219  1469  1829  2028  2134  2266  2414
#    2438  2608  2743  2839  3042  3048  3088  3273  3353  3474  3658  4267
#    4841  4877  5077  5147  5190  5304  5610  5640  5745  5805  5836  5912
#    5959  6068  6096  6146  6274  6566  6716  6955  7270  7395  7559  7620
#    7745  7839  7954  8230  8348  8931  9144  9260  9282  9815 10256 10460
# ...

# %%
clean_data = spy.get_model_data("rap", [36.1699, -115.1398], "2023", "08", "21", "12")
# Out:
# > RAP REANALYSIS DATA ACCESS FUNCTION
#   -----------------------------------------
#     > DATASET USED: RAP_25km_anl
#     > COMPLETE --------
#     > RUNTIME: 00:00:49
#     > SUMMARY: 12Z RAP F00 for[36.1699, -115.1398] at 08-21-2023-12Z
#
#     > THERMODYNAMICS ---------------------------------------------
#     --- SBCAPE: 212.2 | MUCAPE: 212.2 | MLCAPE: 151.3 | MUECAPE: 195.8
#     --- MU 0-3: 32.1 | MU 0-6: 209.5 | SB 0-3: 32.1 | SB 0-6: 209.5
#
#     > KINEMATICS -------------------------------------------------
#     --- 0-500 SRW: 21.9 knot | 0-500 SWV: 0.014 | 0-500 SHEAR: 17.7 | 0-500 SRH: 72.0
#     --- 1-3km SRW: 15.3 knot | 1-3km SWV: 0.003 | 1-3km SHEAR: 8.0 | | 1-3km SRH: 36.5
# ...

# %%
dict(clean_data)
# Out:
# {'p': <Quantity([932.  928.  925.  915.  908.5 875.9 850.  813.5 794.  783.7 771.  757.
#   754.8 739.  726.6 718.  700.  699.5 696.  680.  673.1 663.  647.5 598.6
#   556.  553.4 539.  534.  531.  523.  502.  500.  493.  489.  487.  482.
#   479.  472.  470.2 467.  459.  441.  432.  418.  400.  393.  384.  380.7
#   374.  369.  363.  348.9 343.  315.  305.2 300.  299.  276.  258.  250.
#   240.  234.  225.  212.  207.  202.  200.1 200.  192.  182.  167.  162.
#   157.9 156.  150.  136.7 134.  129.  124.1 121.  118.2 117.  110.  100. ], 'hectopascal')>,
#  'z': <Quantity([  697   735   763   854   914  1219  1469  1829  2028  2134  2266  2414
#    2438  2608  2743  2839  3042  3048  3088  3273  3353  3474  3658  4267
#    4841  4877  5077  5147  5190  5304  5610  5640  5745  5805  5836  5912
#    5959  6068  6096  6146  6274  6566  6716  6955  7270  7395  7559  7620
#    7745  7839  7954  8230  8348  8931  9144  9260  9282  9815 10256 10460
# ...

# %%
# !curl https://mesonet.agron.iastate.edu/cgi-bin/request/gis/lsr.py?wfo=VEF&sts=2010-01-01T00:00Z&ets=2025-07-25T00:00Z&fmt=csv
